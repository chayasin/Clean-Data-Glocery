# %%
import pandas as pd

# %%
fk_dat = pd.read_excel('Freshket_complete.xlsx')
mk_dat = pd.read_csv('Makroclick_complete.csv')

# %%
fk_dat.head()
# Out:
#                                       Group  \
# 0  https://www.freshket.co/market/vegetable
# 1  https://www.freshket.co/market/vegetable
# 2  https://www.freshket.co/market/vegetable
# 3  https://www.freshket.co/market/vegetable
# 4  https://www.freshket.co/market/vegetable
#
#                                          Subgroup  \
# 0  https://www.freshket.co/market/vegetable/leafy
# 1  https://www.freshket.co/market/vegetable/leafy
# 2  https://www.freshket.co/market/vegetable/leafy
# 3  https://www.freshket.co/market/vegetable/leafy
# 4  https://www.freshket.co/market/vegetable/leafy
#
#                                              Product              CatagoryAll  \
# 0  https://www.freshket.co/product/detail/%E0%B8%...       ผัก\nผักใบ\nต้นหอม
# 1  https://www.freshket.co/product/detail/%E0%B8%...  ผัก\nผักใบ\nผักกวางตุ้ง
# 2  https://www.freshket.co/product/detail/%E0%B8%...      ผัก\nผักใบ\nผักบุ้ง
# ...

# %%
mk_dat.head()
# Out:
#                       ITEMNAME    ITEMID FULLPRICE DISCOUNT CURPRICE  \
# 0                 ตับหมู 1 กก.  896642.0   152.00       NaN  152.00
# 1               สันในหมู 1 กก.  896650.0   218.00       NaN  218.00
# 2      สามชั้นหมูสดสไลซ์ 1 กก.  896662.0   240.00       NaN  240.00
# 3        เนื้อหมูหั่นแกง 1 กก.  897654.0   188.00       NaN  188.00
# 4  หมูหมักนุ่ม แพ็คละ 500 กรัม  855488.0    95.00       NaN   95.00
#
#   UNITPRICE                                           ITEM_URL  \
# 0   152.00   https://www.makroclick.com/th/products/896642-...
# 1   218.00   https://www.makroclick.com/th/products/896650-...
# 2   240.00   https://www.makroclick.com/th/products/896662-...
# 3   188.00   https://www.makroclick.com/th/products/897654-...
# 4    95.00   https://www.makroclick.com/th/products/855488-...
#
#                                                  IMG  \
# 0  https://ocs-k8s-prod.s3.ap-southeast-1.amazona...
# 1  https://ocs-k8s-prod.s3.ap-southeast-1.amazona...
# ...

# %%
fk_ = fk_dat[['Category1','Category2','Category3','ProductName','ProductID']]
mk_ = mk_dat[['Cate_1','Cate_2','Cate_3','ITEMNAME','ITEMID']]

# %%
fk_.columns = ['Category1','Category2','Category3','ProductName','Freshket_ID']
fk_['Source'] = 'Freshket'
fk_ = fk_[['Source','Category1','Category2','Category3','ProductName','Freshket_ID']]
fk_.head()
# Out:
# C:\Users\chaya\AppData\Local\Temp\ipykernel_3560\766845031.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fk_['Source'] = 'Freshket'
#      Source Category1 Category2    Category3               ProductName  \
# 0  Freshket       ผัก     ผักใบ       ต้นหอม   ต้นหอมไทย เจ๊หงส์ส่งผัก
# 1  Freshket       ผัก     ผักใบ  ผักกวางตุ้ง               ผักกวางตุ้ง
# 2  Freshket       ผัก     ผักใบ      ผักบุ้ง  ผักบุ้งจีน เจ๊หงส์ส่งผัก
# 3  Freshket       ผัก     ผักใบ      ผักบุ้ง                ผักบุ้งจีน
# 4  Freshket       ผัก     ผักใบ      ผักบุ้ง     ผักบุ้งจีน คัดตัดแต่ง
#
#    Freshket_ID
# 0        33053
# 1        28943
# 2        33009
# 3        26193
# 4         9709

# %%
mk_.columns = ['Category1','Category2','Category3','ProductName','Makro_ID']
mk_['Source'] = 'Makroclick'
mk_ = mk_[['Source','Category1','Category2','Category3','ProductName','Makro_ID']]
mk_.head()
# Out:
# C:\Users\chaya\AppData\Local\Temp\ipykernel_3560\2198156019.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mk_['Source'] = 'Makroclick'
#        Source   Category1 Category2        Category3  \
# 0  Makroclick  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
# 1  Makroclick  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
# 2  Makroclick  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
# 3  Makroclick  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
# 4  Makroclick  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
#
#                    ProductName  Makro_ID
# 0                 ตับหมู 1 กก.  896642.0
# 1               สันในหมู 1 กก.  896650.0
# 2      สามชั้นหมูสดสไลซ์ 1 กก.  896662.0
# 3        เนื้อหมูหั่นแกง 1 กก.  897654.0
# 4  หมูหมักนุ่ม แพ็คละ 500 กรัม  855488.0

# %%
fk_Meat = fk_[fk_['Category1'] == 'เนื้อสัตว์']
fk_Meat.head()
# Out:
#         Source   Category1 Category2        Category3  \
# 1094  Freshket  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่แข็ง
# 1095  Freshket  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่แข็ง
# 1096  Freshket  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
# 1097  Freshket  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
# 1098  Freshket  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
#
#                                ProductName  Freshket_ID
# 1094     หมูสับ/เนื้อหมูบดหยาบ B (แช่แข็ง)        31126
# 1095  หมูสับ/เนื้อหมูบดละเอียด A (แช่แข็ง)        31124
# 1096                              สันคอหมู        10412
# 1097                             สันนอกหมู        31766
# 1098                หมูสามชั้นแผ่น ตราซีพี        21668

# %%
mk_Meat = mk_[mk_['Category1'] == 'เนื้อสัตว์']
mk_Meat.head()
# Out:
#        Source   Category1 Category2        Category3  \
# 0  Makroclick  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
# 1  Makroclick  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
# 2  Makroclick  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
# 3  Makroclick  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
# 4  Makroclick  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
#
#                    ProductName  Makro_ID
# 0                 ตับหมู 1 กก.  896642.0
# 1               สันในหมู 1 กก.  896650.0
# 2      สามชั้นหมูสดสไลซ์ 1 กก.  896662.0
# 3        เนื้อหมูหั่นแกง 1 กก.  897654.0
# 4  หมูหมักนุ่ม แพ็คละ 500 กรัม  855488.0

# %%
fk_Meat.to_excel('fk_meat.xlsx', index=False)
mk_Meat.to_excel('mk_meat.xlsx', index=False)

# %%
fk_Meat[fk_Meat['ProductName'].str.contains('หมู')]
# Out:
#         Source   Category1 Category2        Category3  \
# 1094  Freshket  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่แข็ง
# 1095  Freshket  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่แข็ง
# 1096  Freshket  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
# 1097  Freshket  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
# 1098  Freshket  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
# ...        ...         ...       ...              ...
# 1173  Freshket  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
# 1174  Freshket  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
# 1175  Freshket  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่แข็ง
# 1176  Freshket  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่แข็ง
# 1177  Freshket  เนื้อสัตว์  เนื้อหมู  เนื้อหมูแช่เย็น
#
#                                      ProductName  Freshket_ID
# 1094           หมูสับ/เนื้อหมูบดหยาบ B (แช่แข็ง)        31126
# 1095        หมูสับ/เนื้อหมูบดละเอียด A (แช่แข็ง)        31124
# 1096                                    สันคอหมู        10412
# 1097                                   สันนอกหมู        31766
# ...
